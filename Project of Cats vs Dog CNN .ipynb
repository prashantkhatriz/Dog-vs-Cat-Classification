# %%
# Install & Import Libraries
# %pip install torch torchvision matplotlib pillow

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from PIL import Image
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Collecting torch
#   Downloading torch-2.8.0-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting pillow
#   Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: setuptools in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from torch) (78.1.1)
# Collecting numpy (from torchvision)
#   Downloading numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp312-cp312-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from matplotlib) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prash\anaconda3\envs\newencriment\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.8.0-cp312-cp312-win_amd64.whl (241.3 MB)
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 1.0/241.3 MB 2.5 MB/s eta 0:01:36
#    ---------------------------------------- 1.6/241.3 MB 2.7 MB/s eta 0:01:29
#    ---------------------------------------- 2.6/241.3 MB 3.1 MB/s eta 0:01:16
#     --------------------------------------- 3.1/241.3 MB 3.1 MB/s eta 0:01:17
#     --------------------------------------- 4.2/241.3 MB 3.4 MB/s eta 0:01:11
#     --------------------------------------- 5.0/241.3 MB 3.5 MB/s eta 0:01:09
#     --------------------------------------- 5.5/241.3 MB 3.4 MB/s eta 0:01:11
#     --------------------------------------- 6.0/241.3 MB 3.4 MB/s eta 0:01:09
#    - -------------------------------------- 6.8/241.3 MB 3.4 MB/s eta 0:01:10
#    - -------------------------------------- 7.6/241.3 MB 3.4 MB/s eta 0:01:10
#    - -------------------------------------- 8.4/241.3 MB 3.4 MB/s eta 0:01:09
#    - -------------------------------------- 9.2/241.3 MB 3.5 MB/s eta 0:01:08
#    - -------------------------------------- 10.0/241.3 MB 3.5 MB/s eta 0:01:07
#    - -------------------------------------- 10.7/241.3 MB 3.5 MB/s eta 0:01:06
#    - -------------------------------------- 11.3/241.3 MB 3.5 MB/s eta 0:01:07
#    - -------------------------------------- 12.1/241.3 MB 3.4 MB/s eta 0:01:07
#    -- ------------------------------------- 12.8/241.3 MB 3.5 MB/s eta 0:01:06
#    -- ------------------------------------- 13.6/241.3 MB 3.5 MB/s eta 0:01:06
#    -- ------------------------------------- 14.4/241.3 MB 3.5 MB/s eta 0:01:06
#    -- ------------------------------------- 15.2/241.3 MB 3.5 MB/s eta 0:01:05
#    -- ------------------------------------- 16.0/241.3 MB 3.5 MB/s eta 0:01:05
#    -- ------------------------------------- 16.8/241.3 MB 3.5 MB/s eta 0:01:04
#    -- ------------------------------------- 17.8/241.3 MB 3.6 MB/s eta 0:01:03
#    --- ------------------------------------ 18.6/241.3 MB 3.6 MB/s eta 0:01:03
#    --- ------------------------------------ 19.4/241.3 MB 3.6 MB/s eta 0:01:02
#    --- ------------------------------------ 20.2/241.3 MB 3.6 MB/s eta 0:01:02
#    --- ------------------------------------ 20.7/241.3 MB 3.6 MB/s eta 0:01:02
#    --- ------------------------------------ 21.5/241.3 MB 3.6 MB/s eta 0:01:01
#    --- ------------------------------------ 22.3/241.3 MB 3.6 MB/s eta 0:01:01
#    --- ------------------------------------ 23.3/241.3 MB 3.6 MB/s eta 0:01:01
#    --- ------------------------------------ 23.9/241.3 MB 3.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 24.6/241.3 MB 3.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 25.4/241.3 MB 3.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 26.5/241.3 MB 3.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 27.3/241.3 MB 3.6 MB/s eta 0:00:59
#    ---- -----------------------------------
2 MB/s eta 0:00:20
#    ----------------------- ---------------- 139.2/241.3 MB 5.3 MB/s eta 0:00:20
#    ----------------------- ---------------- 141.3/241.3 MB 5.3 MB/s eta 0:00:19
#    ----------------------- ---------------- 143.1/241.3 MB 5.3 MB/s eta 0:00:19
#    ------------------------ --------------- 146.0/241.3 MB 5.4 MB/s eta 0:00:18
#    ------------------------ --------------- 148.6/241.3 MB 5.4 MB/s eta 0:00:18
#    ------------------------ --------------- 150.7/241.3 MB 5.5 MB/s eta 0:00:17
#    ------------------------- -------------- 153.4/241.3 MB 5.5 MB/s eta 0:00:16
#    ------------------------- -------------- 156.2/241.3 MB 5.6 MB/s eta 0:00:16
#    -------------------------- ------------- 158.6/241.3 MB 5.6 MB/s eta 0:00:15
#    -------------------------- ------------- 161.0/241.3 MB 5.7 MB/s eta 0:00:15
#    --------------------------- ------------ 163.6/241.3 MB 5.7 MB/s eta 0:00:14
#    --------------------------- ------------ 166.2/241.3 MB 5.8 MB/s eta 0:00:14
#    --------------------------- ------------ 168.8/241.3 MB 5.8 MB/s eta 0:00:13
#    ---------------------------- ----------- 171.4/241.3 MB 5.9 MB/s eta 0:00:12
#    ---------------------------- ----------- 174.1/241.3 MB 5.9 MB/s eta 0:00:12
#    ----------------------------- ---------- 176.7/241.3 MB 6.0 MB/s eta 0:00:11
#    ----------------------------- ---------- 179.3/241.3 MB 6.0 MB/s eta 0:00:11
#    ------------------------------ --------- 181.4/241.3 MB 6.1 MB/s eta 0:00:10
#    ------------------------------ --------- 184.0/241.3 MB 6.1 MB/s eta 0:00:10
#    ------------------------------ --------- 186.6/241.3 MB 6.2 MB/s eta 0:00:09
#    ------------------------------- -------- 189.3/241.3 MB 6.2 MB/s eta 0:00:09
#    ------------------------------- -------- 191.9/241.3 MB 6.3 MB/s eta 0:00:08
#    -------------------------------- ------- 194.5/241.3 MB 6.4 MB/s eta 0:00:08
#    -------------------------------- ------- 197.1/241.3 MB 6.4 MB/s eta 0:00:07
#    --------------------------------- ------ 200.0/241.3 MB 6.5 MB/s eta 0:00:07
#    --------------------------------- ------ 202.4/241.3 MB 6.6 MB/s eta 0:00:06
#    --------------------------------- ------ 205.0/241.3 MB 6.6 MB/s eta 0:00:06
#    ---------------------------------- ----- 207.9/241.3 MB 6.7 MB/s eta 0:00:05
#    ---------------------------------- ----- 210.5/241.3 MB 6.8 MB/s eta 0:00:05
#    ----------------------------------- ---- 213.4/241.3 MB 6.8 MB/s eta 0:00:05
#    ----------------------------------- ---- 216.0/241.3 MB 6.9 MB/s eta 0:00:04
#    ------------------------------------ --- 218.1/241.3 MB 6.9 MB/s eta 0:00:04
#    ------------------------------------ --- 221.0/241.3 MB 7.0 MB/s eta 0:00:03
#    ------------------------------------- -- 223.3/241.3 MB 7.1 MB/s eta 0:00:03
#    ------------------------------------- -- 225.7/241.3 MB 7.1 MB/s eta 0:00:03
#    ------------------------------------- -- 228.3/241.3 MB 7.2 MB/s eta 0:00:02
#    -------------------------------------- - 230.7/241.3 MB 7.2 MB/s eta 0:00:02
#    -------------------------------------- - 233.3/241.3 MB 7.3 MB/s eta 0:00:02
#    ---------------------------------------  235.7/241.3 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  237.8/241.3 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  240.4/241.3 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.3 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.3 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.3 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 241.3/241.3 MB 7.4 MB/s eta 0:00:00
# Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 9.6 MB/s eta 0:00:00
# Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------ --------------------------- 2.6/8.1 MB 12.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 10.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 9.5 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------- ------------------------ 2.6/7.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/7.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 9.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------------- ------- 1.8/2.3 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading numpy-2.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 10.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.8 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/12.8 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.8 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 10.5 MB/s eta 0:00:00
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Installing collected packages: mpmath, sympy, pyparsing, pillow, numpy, networkx, kiwisolver, fsspec, fonttools, filelock, cycler, torch, contourpy, torchvision, matplotlib
#
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    -- -------------------------------------  1/15 [sympy]
#    ----- ----------------------------------  2/15 [pyparsing]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------- --------------------------  5/15 [networkx]
#    ------------------ ---------------------  7/15 [fsspec]
#    ------------------ ---------------------  7/15 [fsspec]
#    ------------------ ---------------------  7/15 [fsspec]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    ------------------------ ---------------  9/15 [filelock]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    ----------------------------- ---------- 11/15 [torch]
#    -------------------------------- ------- 12/15 [contourpy]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ---------------------------------- ----- 13/15 [torchvision]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ---------------------------------------- 15/15 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 filelock-3.19.1 fonttools-4.59.2 fsspec-2025.7.0 kiwisolver-1.4.9 matplotlib-3.10.5 mpmath-1.3.0 networkx-3.5 numpy-2.3.2 pillow-11.3.0 pyparsing-3.2.3 sympy-1.14.0 torch-2.8.0 torchvision-0.23.0
# Note: you may need to restart the kernel to use updated packages.
# Using: cpu

# %%
# Data Preparation & Augmentation
transform_train = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

transform_val = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Assuming dataset is in folders: data/train & data/val
if not os.path.exists("data/train") or not os.path.exists("data/val"):
    raise FileNotFoundError("Please make sure 'data/train' and 'data/val' directories exist and contain images.")

train_data = datasets.ImageFolder(root="data/train", transform=transform_train)
val_data   = datasets.ImageFolder(root="data/val", transform=transform_val)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_data, batch_size=32, shuffle=False)

print("Classes:", train_data.classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 18
#      16 # Assuming dataset is in folders: data/train & data/val
#      17 if not os.path.exists("data/train") or not os.path.exists("data/val"):
# ---> 18     raise FileNotFoundError("Please make sure 'data/train' and 'data/val' directories exist and contain images.")
#      20 train_data = datasets.ImageFolder(root="data/train", transform=transform_train)
#      21 val_data   = datasets.ImageFolder(root="data/val", transform=transform_val)
#
# FileNotFoundError: Please make sure 'data/train' and 'data/val' directories exist and contain images.

# %%
# Define CNN Model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 32 * 32, 128)
        self.fc2 = nn.Linear(128, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.sigmoid(self.fc2(x))
        return x

model = CNNModel().to(device)

# %%
# Loss & Optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training Loop
num_epochs = 10
train_acc, val_acc = [], []

for epoch in range(num_epochs):
    model.train()
    correct, total = 0, 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        predicted = (outputs > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
    
    train_accuracy = 100 * correct / total
    train_acc.append(train_accuracy)

    # Validation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device).float().unsqueeze(1)
            outputs = model(images)
            predicted = (outputs > 0.5).float()
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    val_accuracy = 100 * correct / total
    val_acc.append(val_accuracy)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Acc: {train_accuracy:.2f}%, Val Acc: {val_accuracy:.2f}%")

# %%
# Plot Accuracy Graph
plt.plot(range(1, num_epochs+1), train_acc, label="Train Accuracy")
plt.plot(range(1, num_epochs+1), val_acc, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.show()

# %%
# Save the Trained Model
torch.save(model.state_dict(), "cat_dog_cnn.pth")
print("Model saved successfully!")

# %%
# Load Model
loaded_model = CNNModel().to(device)
loaded_model.load_state_dict(torch.load("cat_dog_cnn.pth", map_location=device))
loaded_model.eval()
print("Model loaded successfully!")

# %%
# Predict on External Image
def predict_image(image_path, model):
    transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])
    
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)
    
    with torch.no_grad():
        output = model(image)
        prediction = (output > 0.5).float().item()
    
    class_names = train_data.classes
    print(f"Prediction: {class_names[int(prediction)]}")
    return class_names[int(prediction)]

# Example
# test_image_path = "test_cat.jpg"
# predict_image(test_image_path, loaded_model)
